# %% [markdown]
# # 1 import req lib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:/Users/Nihala Sherin A/Downloads/track_my_bus_passenger_dataset.csv")
df
# Out:
#      Bus_ID Route_ID Stop_ID   Latitude  Longitude Day_Type  Hour  \
# 0      B048       R3      S1   9.092386  74.197544  Weekday    12
# 1      B005       R3     S20   8.433561  74.707870  Weekday    20
# 2      B026       R7     S15   9.267008  74.125261  Weekday    17
# 3      B004       R9      S2  12.293522  74.913053  Weekday    20
# 4      B020       R1     S17  10.582374  76.662323  Weekend    19
# ...     ...      ...     ...        ...        ...      ...   ...
# 1995   B030      R10      S6   8.669577  75.747942  Weekday    19
# 1996   B024       R1      S7  11.807051  77.704981  Weekday    10
# 1997   B024       R2     S15   8.712667  74.594113  Weekend     6
# 1998   B024       R9     S15  12.933870  74.443785  Weekend    13
# 1999   B042       R1     S18   9.548617  74.159848  Weekday    15
#
#       Distance_km Traffic_Level  Bus_Capacity  Passenger_Count
# 0           13.23          High            50               49
# 1           13.80           Low            60               62
# 2           14.16           Low            60               74
# 3            5.89           Low            40               62
# 4           14.62          High            40               68
# ...           ...           ...           ...              ...
# 1995         7.62           Low            50               62
# 1996         6.41        Medium            60               65
# 1997        20.27          High            60               47
# 1998         6.53          High            60               44
# 1999         6.58           Low            60               65
#
# [2000 rows x 11 columns]

# %%
df.head()
# Out:
#   Bus_ID Route_ID Stop_ID   Latitude  Longitude Day_Type  Hour  Distance_km  \
# 0   B048       R3      S1   9.092386  74.197544  Weekday    12        13.23
# 1   B005       R3     S20   8.433561  74.707870  Weekday    20        13.80
# 2   B026       R7     S15   9.267008  74.125261  Weekday    17        14.16
# 3   B004       R9      S2  12.293522  74.913053  Weekday    20         5.89
# 4   B020       R1     S17  10.582374  76.662323  Weekend    19        14.62
#
#   Traffic_Level  Bus_Capacity  Passenger_Count
# 0          High            50               49
# 1           Low            60               62
# 2           Low            60               74
# 3           Low            40               62
# 4          High            40               68

# %% [markdown]
# # 2 EDA

# %%
# passenger count distribution
plt.figure()
sns.histplot(df['Passenger_Count'], bins=30)
plt.title("Passenger Count Distribution")
plt.show()

# %%
# passenger demand by hour
plt.figure()
sns.boxplot(x='Hour', y='Passenger_Count', data=df)
plt.title("Passenger Demand by Hour")
plt.show()

# %%
# weekday vs weekend passenger count
plt.figure()
sns.barplot(x='Day_Type', y='Passenger_Count', data=df)
plt.title("Passenger Count: Weekday vs Weekend")
plt.show()

# %% [markdown]
# # 3 Features eng

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for col in ['Route_ID', 'Stop_ID', 'Day_Type', 'Traffic_Level']:
    df[col] = le.fit_transform(df[col])
x = df[['Route_ID', 'Stop_ID', 'Day_Type', 'Hour',
        'Distance_km', 'Traffic_Level', 'Bus_Capacity']]
y = df['Passenger_Count']

# %% [markdown]
# # 4 Train Test

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=30)

# %% [markdown]
# # 5 Modeling

# %%
# from sklearn.linear_model import LinearRegression
# lr = LinearRegression()
# lr.fit(X_train, y_train)
# from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
# y_pred = lr.predict(X_test)
# mae = mean_absolute_error(y_test, y_pred)
# mse = mean_squared_error(y_test, y_pred)
# rmse = np.sqrt(mse)
# r2 = r2_score(y_test, y_pred)
# print("MAE:", mae)
# print("MSE:", mse)
# print("RMSE:", rmse)
# print("R2 Score:", r2)
# print(lr.score(X_test,y_test))

# %%
# from sklearn.svm import SVR
# from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score


# model = SVR(kernel='rbf', C=30, gamma='auto')

# model.fit(X_train, y_train)

# y_pred_svm = model.predict(X_test)

# # Evaluation
# print("MAE:", mean_absolute_error(y_test, y_pred_svm))
# print("RMSE:", mean_squared_error(y_test, y_pred_svm))
# print("R2 Score:", r2_score(y_test, y_pred_svm))

# %%
# from sklearn.ensemble import RandomForestRegressor
# rf = RandomForestRegressor(random_state=30)
# rf.fit(X_train, y_train)

# y_pred_rf = rf.predict(X_test)

# print("Random Forest (Before Tuning)")
# print("MAE:", mean_absolute_error(y_test, y_pred_rf))
# print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred_rf)))
# print("R2:", r2_score(y_test, y_pred_rf))
# print(rf.score(X_test,y_test))

# %% [markdown]
# # 6 hyper parameter tuning

# %%
# from sklearn.model_selection import GridSearchCV
# param_grid = {
#     'n_estimators': [50, 100],
#     'max_depth': [None, 10, 20],
#     'min_samples_split': [2, 5],
#     'min_samples_leaf': [1, 2]
# }

# grid = GridSearchCV(
#     RandomForestRegressor(random_state=30),
#     param_grid,
#     cv=3,
#     scoring='neg_mean_squared_error',
#     n_jobs=-1
# )

# print(grid.fit(X_train, y_train))
# print(grid.score(X_test,y_test))
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
import pandas as pd
import numpy as np
model_params = {
    'linear_regression': {
        'model': LinearRegression(),
        'params': {}   # No hyperparameters for basic Linear Regression
    },
    
    'svr': {
        'model': SVR(),
        'params': {
            'C': [1, 10, 30],
            'gamma': ['scale', 'auto'],
            'kernel': ['rbf']
        }
    },
    
    'random_forest': {
        'model': RandomForestRegressor(random_state=30),
        'params': {
            'n_estimators': [50, 100],
            'max_depth': [5, 10, None],
            'min_samples_split': [2, 5],
            'min_samples_leaf': [1, 2]
        }
    }
}

# %%
print("Best Parameters:", grid.best_params_)
best_model = grid.best_estimator_
y_pred = best_model.predict(X_test)
print("Best RMSE:", np.sqrt(-grid.best_score_))  #best score
# Out:
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 50}
# Best RMSE: 7.808172418408631

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

y_pred = best_model.predict(X_test)

print("Random Forest (Best Model After Hyperparameter Tuning)")
print("MAE:", mean_absolute_error(y_test, y_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))
print("R2 Score:", r2_score(y_test, y_pred))
# Out:
# Random Forest (Best Model After Hyperparameter Tuning)
# MAE: 6.456823112788807
# RMSE: 7.687108779097274
# R2 Score: 0.5935156829408974

# %%
df['Predicted_Passenger_Count'] = best_model.predict(x)
df.to_csv("passenger_demand_predictions.csv", index=False)

# %%
import numpy as np
import pandas as pd

y_pred = best_model.predict(X_test)

y_pred_int = np.round(y_pred).astype(int)


results_df = pd.DataFrame({
    "Actual Passenger Count": y_test.values if hasattr(y_test, "values") else y_test,
    "Predicted Passenger Count": y_pred_int
})

results_df.head()
# Out:
#    Actual Passenger Count  Predicted Passenger Count
# 0                      56                         62
# 1                      68                         74
# 2                      34                         40
# 3                      57                         50
# 4                      59                         50

# %%
import pickle
with open('model.pkl','wb') as file:
  pickle.dump('best_model',file)

# %%
with open('model.pkl','rb')as file:
    mp=pickle.load(file)

# %%
pickle.dump(mp,open('scaler2.sav','wb'))
with open("scaler2.sav", "rb") as file:
    scaler = pickle.load(file)

# %% [markdown]
# Lowest RMSE = Best Model (usually Random Forest)

# %%
# Out:
#      Bus_ID  RouteID  Stop_ID   Latitude  Longitude  Day of Week  Hour  \
# 0      B048        3        0   9.092386  74.197544            0    12
# 1      B005        3       12   8.433561  74.707870            0    20
# 2      B026        7        6   9.267008  74.125261            0    17
# 3      B004        9       11  12.293522  74.913053            0    20
# 4      B020        0        8  10.582374  76.662323            1    19
# ...     ...      ...      ...        ...        ...          ...   ...
# 1995   B030        1       16   8.669577  75.747942            0    19
# 1996   B024        0       17  11.807051  77.704981            0    10
# 1997   B024        2        6   8.712667  74.594113            1     6
# 1998   B024        9        6  12.933870  74.443785            1    13
# 1999   B042        0        9   9.548617  74.159848            0    15
#
#       Distance_km  Traffic_Level  Bus_Capacity  Passenger_Count  \
# 0           13.23              0            50               49
# 1           13.80              1            60               62
# 2           14.16              1            60               74
# 3            5.89              1            40               62
# 4           14.62              0            40               68
# ...           ...            ...           ...              ...
# 1995         7.62              1            50               62
# 1996         6.41              2            60               65
# 1997        20.27              0            60               47
# 1998         6.53              0            60               44
# 1999         6.58              1            60               65
#
#       Predicted_Passenger_Count
# 0                     56.106940
# 1                     66.777616
# 2                     64.620168
# 3                     69.216616
# 4                     62.876356
# ...                         ...
# 1995                  65.509654
# 1996                  62.610183
# 1997                  42.329645
# 1998                  50.038738
# 1999                  60.031522
#
# [2000 rows x 12 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 df.columns = ["Hour","Day of Week","RouteID"]
#       2 df
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\generic.py:6335, in NDFrame.__setattr__(self, name, value)
#    6333 try:
#    6334     object.__getattribute__(self, name)
# -> 6335     return object.__setattr__(self, name, value)
#    6336 except AttributeError:
#    6337     pass
#
# File pandas/_libs/properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\generic.py:817, in NDFrame._set_axis(self, axis, labels)
#     812 """
#     813 This is called from the cython code when we set the `index` attribute
#     814 directly, e.g. `series.index = [1, 2, 3]`.
#     815 """
#     816 labels = ensure_index(labels)
# --> 817 self._mgr.set_axis(axis, labels)
#     818 self._clear_item_cache()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\internals\managers.py:238, in BaseBlockManager.set_axis(self, axis, new_labels)
#     236 def set_axis(self, axis: AxisInt, new_labels: Index) -> None:
#     237     # Caller is responsible for ensuring we have an Index object.
# --> 238     self._validate_set_axis(axis, new_labels)
#     239     self.axes[axis] = new_labels
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\internals\base.py:98, in DataManager._validate_set_axis(self, axis, new_labels)
#      95     pass
#      97 elif new_len != old_len:
# ---> 98     raise ValueError(
#      99         f"Length mismatch: Expected axis has {old_len} elements, new "
#     100         f"values have {new_len} elements"
#     101     )
#
# ValueError: Length mismatch: Expected axis has 12 elements, new values have 3 elements
